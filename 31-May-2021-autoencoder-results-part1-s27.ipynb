# %% [markdown]
# ## This page shows the test results of an autoencoder where the testing waveform is from Ott, et al, 2013

# %%
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %% [markdown]
# ## The following are the results for 3000 test samples where the time shift, phase shift, amplitude scale factors and the waveform have not been used to train the autoencoder.

# %% [markdown]
# ### To quantify how good the reconstruction of a waveform is, a quantity, referred to as the correlation factor (CF), defined below, is used,
#
# ### $C = \frac{(\boldsymbol{h}^{r}, \boldsymbol{h}^{t})}{\sqrt{(\boldsymbol{h}^{r} , \boldsymbol{h}^{r}) (\boldsymbol{h}^{t}, \boldsymbol{h}^{t})}}$,
# ### where $C$ is the CF, $h^{r}$ is the reconstruted waveform from the trained autoencoder in vector form, and $h^{t}$ the target waveform in vector form.
# ### Both $h^{r}$ and $h^{t}$ can either be in the time (T) domain or the time-frequency (TF) domain,
# ### and $(,)$ is the scalar product between two vectors, given by
# ### $(\boldsymbol{a}, \boldsymbol{b}) = \sum_n a_n b_n$.
# ### The CF is used both in the time domain and the time-frequency domain.
# ### Larger value of CF means closer matching between $h^{r}$ and $h^{t}$.

# %% [markdown]
# ## Figure 1.  The distribution of CF in the TF domain for the 3000 test samples.
# ## Left panel : the distribution of CF between $h^{r}$ and $h^{t}$  in the TF domain.
# ## Right panel : the distribution of CF between the  $h^{r}$ and random values following Gaussian distribution.

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/cf_dist_in_tf_and_random.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 2. The test sample with the largest CF in the TF domain (0.91)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/tf_best_example.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 3. The test sample with the smallest CF in the TF domain (0.6)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/tf_worst_example.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 4.  The distribution of the CF in the T domain for the 3000 test samples.
# ## Left panel : the distribution of the CF between $h^{r}$ and $h^{t}$  in the T domain.
# ## Right panel : the distribution of the CF between $h^{r}$  and random values following Gaussian distribution.

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/cf_dist_in_td_and_random.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 5. The test sample with the largest CF in the T domain (0.79)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/td_best_example.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 6. The test sample with the smallest CF in the T domain (0.19)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/td_worst_example.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 7. The spectrogram of an example waveform from the autoencoder and that of randomly generated values

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/tf_random.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 8. The distributions of the ampltide scaling factors for the 3000 samples and samples with CF less than a certain value

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/Ampf_dist_both.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 9. The distributions of the outputs from the latent space for the 3000 samples
# ## The curves on top are normal distributions

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/latent_space.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 10. KL loss and loss vs epochs for the last 1000 epochs

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/combined_loss.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 11. The function used to normalise the target waveforms

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('Ott_2013/normalised_function.png') 
plt.imshow(x)
plt.axis('off')

plt.show()
