# %% [markdown]
# ## This page shows the test results of an autoencoder

# %%
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt

# %% [markdown]
# ## The following are the results for 2800 testing samples where the time shift, phase shift and amplitude scale factors have not been used to train the autoencoder.

# %% [markdown]
# ## To quantify how good the reconstruction of a waveform is, a quantity, referred to as the correlation factor, defined below, was used,
#
# ## $C = \frac{(h^{r}, h^{t})}{\sqrt{(h^{r} , h^{r}) (h^{t}, h^{t})}}$
# ## where C is the correlation factor, $h^{r}$ is the reconstruted waveform from the trained autoencoder, and $h^{t}$ the target waveform
# ## and $(,)$ is the scalar product between two waveforms, given by
# ## $(a, b) = \int a(t)b(t)dt$
#
# ## The range for this value is [-1, 1].
# ## a correlation factor of 1 means a perfect matching, -1 opposite matching

# %% [markdown]
# ## Figure 1.  The distribution of the correlation factors for the 2800 test samples

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/cf_in_td.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 2. The test sample with the largest correlation factor (0.903)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/791_0.903_combined.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 3. The test sample with the smallest correlation factor (-0.141)

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/1850_-0.141_combined.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 4. The distributions of the outputs from the latent space for the 2800 samples

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/latentspace.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 5. KL loss and loss vs epochs for the last 2000 epochs

# %%
fig = plt.figure(figsize=(43.5,20.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/combined_loss.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 6. KL weight vs epochs for the last 2000 epochs

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/2_2_2021_17_32_48/KL_weights26_2_2021_17_32_48.png') 
plt.imshow(x)
plt.axis('off')

plt.show()

# %% [markdown]
# ## Figure 7. The function used to normalise the target waveforms

# %%
fig = plt.figure(figsize=(25.5,12.25), dpi= 100, facecolor='w', edgecolor='k')
a=fig.add_subplot(1, 2, 1)
x = Image.open('03-Mar-2021/normalised_function.png') 
plt.imshow(x)
plt.axis('off')

plt.show()
